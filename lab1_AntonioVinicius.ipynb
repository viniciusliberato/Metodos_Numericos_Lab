# %% [markdown]
# # Laboratório 1 - Métodos Numéricos - Antônio Vinícius Liberato

# %% [markdown]
# # Comandos básicos: Função em Python
# ### Exemplo: funcao(entrada1,entrada2)

# %%
x = 200

# %%
print('fit a model with', x,'variables')
# Out:
# fit a model with 200 variables

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %% [markdown]
# ### Somar dois números é direto:

# %%
10 + 30
# Out:
# 40

# %% [markdown]
# ### Texto em Python é string

# %%
disciplina = "metodos numericos"
disciplina
# Out:
# 'metodos numericos'

# %% [markdown]
# #### Markdown são textos para situar os códigos

# %% [markdown]
# ## Listas e tuplas

# %%
x = [1,2,3,4,5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y = (3,2,1,4)
y
# Out:
# (3, 2, 1, 4)

# %% [markdown]
# ## Operações de listas -> não soma, concatena

# %%
z = [1,2,2,3,4,5]
x+z
# Out:
# [1, 2, 3, 4, 5, 1, 2, 2, 3, 4, 5]

# %% [markdown]
# # Biblioteca Numpy

# %%
import numpy as np

# %% [markdown]
# ### Array em numpy e operações

# %%
x = np.array([1,2,3,4])
y = np.array([3,2,1,4])
x + y
# Out:
# array([4, 4, 4, 8])

# %% [markdown]
# ### Vetor bidimensional em numpy -> arrays de duas dimensões

# %%
z = np.array([[1,2,3],[4,5,6]])
z
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ### Dimensões do vetor e tipo

# %%
z.ndim
# Out:
# 2

# %%
z.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Importando bibliotecas

# %%
import ISLP
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lendo o dataset de regressão limpo
df_pred = pd.read_csv("dataset_regressao_limpo.csv")

# %%
# Usando a função pd.plotting.scatter.matrix() para criar um gráfico de dispersão
pd.plotting.scatter_matrix(df_pred, figsize=(10, 10), diagonal='kde')
# Out:
# array([[<Axes: xlabel='AMBIENT_TEMPERATURE', ylabel='AMBIENT_TEMPERATURE'>,
#         <Axes: xlabel=' MODULE_TEMPERATURE', ylabel='AMBIENT_TEMPERATURE'>,
#         <Axes: xlabel=' IRRADIATION           ', ylabel='AMBIENT_TEMPERATURE'>,
#         <Axes: xlabel=' DC_POWER', ylabel='AMBIENT_TEMPERATURE'>],
#        [<Axes: xlabel='AMBIENT_TEMPERATURE', ylabel=' MODULE_TEMPERATURE'>,
#         <Axes: xlabel=' MODULE_TEMPERATURE', ylabel=' MODULE_TEMPERATURE'>,
#         <Axes: xlabel=' IRRADIATION           ', ylabel=' MODULE_TEMPERATURE'>,
#         <Axes: xlabel=' DC_POWER', ylabel=' MODULE_TEMPERATURE'>],
#        [<Axes: xlabel='AMBIENT_TEMPERATURE', ylabel=' IRRADIATION           '>,
#         <Axes: xlabel=' MODULE_TEMPERATURE', ylabel=' IRRADIATION           '>,
#         <Axes: xlabel=' IRRADIATION           ', ylabel=' IRRADIATION           '>,
#         <Axes: xlabel=' DC_POWER', ylabel=' IRRADIATION           '>],
# ...
